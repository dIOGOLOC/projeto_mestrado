# %% [markdown]
# <h1>Exemplo de Como são adquiridos os dados sismológicos<h1>

# %%
from IPython.display import Image
import numpy as np
import fatiando
from matplotlib import animation
from fatiando import gridder, utils
from fatiando.seismic import wavefd
from fatiando.vis import mpl

# %%
area = [0, 500*10**3, 0, 200*10**3]
velocityp = utils.fromimage('moho.png', ranges=[5500, 6500]).astype(np.float)
velocitys = utils.fromimage('moho.png', ranges=[3000, 4000]).astype(np.float)
density = utils.fromimage('moho.png', ranges=[2670, 3300]).astype(np.float)

lamb = wavefd.lame_lamb(velocityp, velocitys, density)
mu = wavefd.lame_mu(velocitys, density)
shape = mu.shape

mpl.figure()
mpl.imshow(velocityp[::-1], extent=area, cmap=mpl.cm.gray_r)
mpl.ylim(area[2:][::-1])
mpl.colorbar()
mpl.m2km()
mpl.savefig('velocity-model.png')
mpl.show()
Image(filename='velocity-model.png')

# %%
sources = wavefd.blast_source(5000,190000,area,shape,100000,0.5,delay = 2)
dt = wavefd.maxdt(area, shape, velocityp.max())
duration = 80
maxit = int(duration / dt)
stations = [[400000, 0]]  # x, z coordinate of the seismometer
snapshots = int(1 / dt)  # Plot a snapshot of the simulation every 0.5 seconds
simulation = wavefd.elastic_psv(lamb, mu, density, area, dt, maxit, sources,
                                stations, snapshots, padding=50, taper=0.01,
                                xz2ps=True)

# %%
background = 10 ** -5 * ((density - density.min()) / density.max())
fig = mpl.figure(figsize=(10, 8))
mpl.subplots_adjust(right=0.98, left=0.11, hspace=0.3, top=0.93)
mpl.subplot(3, 1, 1)
mpl.title('x seismogram')
xseismogram, = mpl.plot([], [], '-k')
mpl.xlim(0, duration)
mpl.ylim(-0.05, 0.05)
mpl.ylabel('Amplitude')
mpl.subplot(3, 1, 2)
mpl.title('z seismogram')
zseismogram, = mpl.plot([], [], '-k')
mpl.xlim(0, duration)
mpl.ylim(-0.05, 0.05)
mpl.ylabel('Amplitude')
ax = mpl.subplot(3, 1, 3)
mpl.title('time: 0.0 s')
wavefield = mpl.imshow(background, extent=area, cmap=mpl.cm.gray_r,
                       vmin=-0.00001, vmax=0.00001)
mpl.points(stations, '^b', size=8)
mpl.text(500000, 20000, 'Crust')
mpl.text(500000, 60000, 'Mantle')
fig.text(0.7, 0.31, 'Seismometer')
mpl.xlim(area[:2])
mpl.ylim(area[2:][::-1])
mpl.xlabel('x (km)')
mpl.ylabel('z (km)')
mpl.m2km()
times = np.linspace(0, dt * maxit, maxit)
# This function updates the plot every few timesteps


def animate(i):
    t, p, s, xcomp, zcomp = simulation.next()
    mpl.title('time: %0.1f s' % (times[t]))
    wavefield.set_array((background + p + s)[::-1])
    xseismogram.set_data(times[:t + 1], xcomp[0][:t + 1])
    zseismogram.set_data(times[:t + 1], zcomp[0][:t + 1])
    return wavefield, xseismogram, zseismogram


anim = animation.FuncAnimation(
    fig, animate, frames=maxit / snapshots, interval=1)
mpl.show()

# %%
# Plot
background = velocity*2*10**-7
fig = mpl.figure(figsize=(3, 3))
mpl.subplots_adjust(left=0, right=1, bottom=0, top=1)
ax = mpl.gca()
fig.patch.set_visible(False)
ax.axis('off')
wavefield = mpl.imshow(background, extent=area, cmap=mpl.cm.gray_r, vmax=1.05*background.max())
mpl.ylim(area[2:][::-1])
ax.set_xticks([])
ax.set_yticks([])
times = np.linspace(0, dt*maxit, maxit)
frame = 0


def animate(i):
    global frame
    t, u, seismogram = simulation.next()
    wavefield.set_array((background + u)[::-1])
    mpl.savefig('frames/frame%04d.png' % (frame), dpi=50)
    frame += 1
    return wavefield
anim = animation.FuncAnimation(fig, animate, frames=maxit//snapshots, interval=1)
mpl.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-e327e18292a2> in <module>()
#       1 # Plot
# ----> 2 background = velocity*2*10**-7
#       3 fig = mpl.figure(figsize=(3, 3))
#       4 mpl.subplots_adjust(left=0, right=1, bottom=0, top=1)
#       5 ax = mpl.gca()
#
# NameError: name 'velocity' is not defined

# %%
"""
Seismic: 2D finite difference simulation of elastic P and SV wave propagation
in a medium with a discontinuity (i.e., Moho), generating Rayleigh waves
"""
import numpy as np
from matplotlib import animation
from fatiando import gridder
from fatiando.seismic import wavefd
from fatiando.vis import mpl

# Set the parameters of the finite difference grid
shape = (150, 900)
area = [0, 540000, 0, 90000]

# Make a density and wave velocity model
density = 2400 * np.ones(shape)
svel = 3700 * np.ones(shape)
pvel = 6600 * np.ones(shape)
moho = 50
density[moho:] = 2800
svel[moho:] = 4300
pvel[moho:] = 7500
mu = wavefd.lame_mu(svel, density)
lamb = wavefd.lame_lamb(pvel, svel, density)

# Make a wave source from a mexican hat wavelet for the x and z directions
sources = [
    [wavefd.MexHatSource(10000, 10000, area, shape, 100000, 0.5, delay=2)],
    [wavefd.MexHatSource(10000, 10000, area, shape, 100000, 0.5, delay=2)]]

# Get the iterator. This part only generates an iterator object. The actual
# computations take place at each iteration in the for loop below
dt = wavefd.maxdt(area, shape, pvel.max())
duration = 135
maxit = int(duration / dt)
stations = [[100000, 0]]
snapshots = int(1. / dt)
simulation = wavefd.elastic_psv(lamb, mu, density, area, dt, maxit, sources,
                                stations, snapshots, padding=70, taper=0.005,
                                xz2ps=True)

# This part makes an animation using matplotlibs animation API
background = 10 ** -5 * ((density - density.min()) / density.max())
fig = mpl.figure(figsize=(10, 8))
mpl.subplots_adjust(right=0.98, left=0.11, hspace=0.3, top=0.93)
mpl.subplot(3, 1, 1)
mpl.title('x seismogram')
xseismogram, = mpl.plot([], [], '-k')
mpl.xlim(0, duration)
mpl.ylim(-0.05, 0.05)
mpl.ylabel('Amplitude')
mpl.subplot(3, 1, 2)
mpl.title('z seismogram')
zseismogram, = mpl.plot([], [], '-k')
mpl.xlim(0, duration)
mpl.ylim(-0.05, 0.05)
mpl.ylabel('Amplitude')
ax = mpl.subplot(3, 1, 3)
mpl.title('time: 0.0 s')
wavefield = mpl.imshow(background, extent=area, cmap=mpl.cm.gray_r,
                       vmin=-0.00001, vmax=0.00001)
mpl.points(stations, '^b', size=8)
mpl.text(500000, 20000, 'Crust')
mpl.text(500000, 60000, 'Mantle')
fig.text(0.7, 0.31, 'Seismometer')
mpl.xlim(area[:2])
mpl.ylim(area[2:][::-1])
mpl.xlabel('x (km)')
mpl.ylabel('z (km)')
mpl.m2km()
times = np.linspace(0, dt * maxit, maxit)
# This function updates the plot every few timesteps


def animate(i):
    t, p, s, xcomp, zcomp = simulation.next()
    mpl.title('time: %0.1f s' % (times[t]))
    wavefield.set_array((background + p + s)[::-1])
    xseismogram.set_data(times[:t + 1], xcomp[0][:t + 1])
    zseismogram.set_data(times[:t + 1], zcomp[0][:t + 1])
    return wavefield, xseismogram, zseismogram


anim = animation.FuncAnimation(
    fig, animate, frames=maxit / snapshots, interval=1)
mpl.show()
