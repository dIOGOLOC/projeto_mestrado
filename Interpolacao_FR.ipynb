# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['mpl', 'shape']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
from __future__ import print_function
import numpy as np
import matplotlib.pyplot as plt
import obspy
from obspy import Trace
import glob
import os
import shutil
from StringIO import StringIO
import matplotlib.gridspec as gridspec
from fatiando import gridder, utils
from fatiando.vis import mpl
import utm
import shapefile
from matplotlib.collections import PatchCollection

# %% [markdown]
# <h3>Arquivos de Entrada:</h3>

# %%
dados_estacoes = np.genfromtxt('/home/diogo/Copy/Material  ON/Projeto Mestrado/dados_das_estações_ajeitada.csv',delimiter = ',',skip_header = 1,
                               usecols=(1,2,3,4,5,6,7,8))

labels = np.genfromtxt('/home/diogo/Copy/Material  ON/Projeto Mestrado/dados_das_estações_ajeitada.csv',delimiter = ',',dtype = "|S7",
                       usecols = 0,skip_header = 1)

# %%
#para Dados ajeitados

lat_x = dados_estacoes[:,0]
long_y = dados_estacoes[:,1]
alt = dados_estacoes[:,2]
prof = dados_estacoes[:,3]
delta_prof = dados_estacoes[:,4]
vp_vs = dados_estacoes[:,5]
delta_vp_vs = dados_estacoes[:,6]
numero_FR = dados_estacoes[:,7]
prof_nm = prof-alt/1000
hidro1 = shapefile.Reader('/home/diogo/Copy/Material  ON/Projeto Mestrado/shape_area/Riodejaneiro_lito/Hidrografia/SF23_Rio_de_Janeiro_unifilar.shp')
hidro2 = shapefile.Reader('/home/diogo/Copy/Material  ON/Projeto Mestrado/shape_area/Riodejaneiro_lito/Hidrografia/SF23_Rio_de_Janeiro_bifilar.shp')
sf = shapefile.Reader('/home/diogo/Copy/Material  ON/Projeto Mestrado/shape_area/estados_2010.shp')
bat = shapefile.Reader('/home/diogo/Copy/Material  ON/Projeto Mestrado/shape_area/batimetria.shp')
tc = shapefile.Reader('/home/diogo/Copy/Material  ON/Projeto Mestrado/shape_area/SouthAmericaTectonicElements.shp')
lc = shapefile.Reader('/home/diogo/Copy/Material  ON/Projeto Mestrado/shape_area/Riodejaneiro_lito/Litologia/SF23_Riodejaneiro_lito.shp')

# %%
labels = []
shapes = lc.shapes()
records = lc.records()
for rec,shape in zip(records,shapes):
   labels.append(rec[0])

# %%
#labels

label = []
shapes = lc.shapes()
records = lc.records()
for rec,shape in zip(records,shapes):
   label.append(rec[0])
labels1=['k' if j=='D23' else j for i,j in enumerate(label)]
labels2=['k' if j=='D22' else j for i,j in enumerate(labels1)]
labels3=['k' if j=='D21' else j for i,j in enumerate(labels2)]
labels4=['dimgrey' if j=='D20' else j for i,j in enumerate(labels3)]
labels5=['dimgrey' if j=='D19' else j for i,j in enumerate(labels4)]
labels6=['dimgrey' if j=='D18' else j for i,j in enumerate(labels5)]
labels7=['dimgrey' if j=='D17' else j for i,j in enumerate(labels6)]
labels8=['darkgoldenrod' if j=='D16' else j for i,j in enumerate(labels7)]
labels9=['darkgoldenrod' if j=='D15' else j for i,j in enumerate(labels8)]
labels10=['darkgoldenrod' if j=='D14' else j for i,j in enumerate(labels9)]
labels11=['darkgoldenrod' if j=='D13' else j for i,j in enumerate(labels10)]
labels12=['goldenrod' if j=='D12' else j for i,j in enumerate(labels11)]
labels13=['goldenrod' if j=='D11' else j for i,j in enumerate(labels12)]
labels14=['goldenrod' if j=='D10' else j for i,j in enumerate(labels13)]
labels15=['goldenrod' if j=='D09' else j for i,j in enumerate(labels14)]
labels16=['goldenrod' if j=='D08' else j for i,j in enumerate(labels15)]
labels17=['gold' if j=='D07' else j for i,j in enumerate(labels16)]
labels18=['gold' if j=='D06' else j for i,j in enumerate(labels17)]
labels19=['gold' if j=='D05' else j for i,j in enumerate(labels18)]
labels20=['y' if j=='D02' else j for i,j in enumerate(labels19)]
labels21=['y' if j=='D01' else j for i,j in enumerate(labels20)]
labels22=['y' if j=='20' else j for i,j in enumerate(labels21)]
'''for (i, item) in enumerate(labels):
    if len(item) == 180:
        labels[i] = 'w'''
# Out:
# "for (i, item) in enumerate(labels):\n    if len(item) == 180:\n        labels[i] = 'w"

# %%
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111)
color = labels22
for sr in lc.shapeRecords():
    shape = sr.shape
    parts = list(shape.parts) + [len(shape.points)]
    partlims = zip(parts[:-1], parts[1:])
    polygons = [Polygon(shape.points[i1:i2]) for i1, i2 in partlims]
    tectprovince = PatchCollection(polygons,facecolor=color,linewidths=0.5)
    ax.add_collection(tectprovince)
mpl.axis('normal')
mpl.ylim(-26,-20)
mpl.xlim(-48,-42)
# Out:
# (-49, -42)

# %%
for shape in lc.shapes():
# adding polygon(s)
    parts = list(shape.parts) + [len(shape.points)]
    partlims = zip(parts[:-1], parts[1:])
    for i1, i2 in partlims:
        points = shape.points[i1:i2]
        x3, y3 = zip(*points)
        plt.plot(x3,y3 , '-', lw=0.1, color='k')

# %%
labels = []
shapes = lc.shapes()
records = lc.records()
for rec,shape in zip(records,shapes):
    parts = list(shape.parts) + [len(shape.points)]
    partlims = zip(parts[:-1], parts[1:])
    for i1, i2 in partlims:
        points = shape.points[i1:i2]
        x3, y3 = zip(*points)
        labels.append(rec[17])
        plt.plot(long_y,lat_x,'ok')
        plt.plot(x3,y3 , '-', lw=0.1, color='k')

# %%
shape = r.shape
print(r.record[17])
parts = list(shape.parts) + [len(shape.points)]
partlims = zip(parts[:-1], parts[1:])
for i1, i2 in partlims:
    points = shape.points[i1:i2]
    x3, y3 = zip(*points)
    plt.plot(x3,y3 , '-', lw=0.1, color='k')
# Out:
# Mesoz�ico

# %%
plt.plot(long_y,lat_x, '^k', markersize=10)
#mpl.scatter(long_y,lat_x,s=100,c=prof,vmin=min(prof), vmax=max(prof),cmap='bone')
hapes = man.shapes()
records = man.records()
for rec,shape in zip(records,shapes):
    parts = list(shape.parts) + [len(shape.points)]
    partlims = zip(parts[:-1], parts[1:])
    for i1, i2 in partlims:
        points = shape.points[i1:i2]
        x3, y3 = zip(*points)
        plt.plot(x3,y3 , '-', lw=0.1, color='k')    
plt.ylim(-26.5,-19)
plt.xlim(-47.55,-44.5)
# Out:
# (-47.55, -44.5)

# %%
#para Dados não ajeitados

lat_x = np.delete(dados_estacoes[:,0],[6,22,23,24])
long_y = np.delete(dados_estacoes[:,1],[6,22,23,24])
alt = np.delete(dados_estacoes[:,2],[6,22,23,24])
prof = np.delete(dados_estacoes[:,3],[6,22,23,24])
labels = np.delete(labels,[6,22,23,24])
delta_prof = np.delete(dados_estacoes[:,4],[6,22,23,24])
vp_vs = np.delete(dados_estacoes[:,5],[6,22,23,24])
delta_vp_vs = np.delete(dados_estacoes[:,6],[6,22,23,24])
numero_FR = np.delete(dados_estacoes[:,7],[6,22,23,24])
prof_nm = prof-alt/1000

# %%
UTM = np.array([utm.from_latlon(i[0],i[1]) for i in zip(lat_x,long_y)])
UTM_E = np.array([int(float(UTM[i][0])) for i in xrange(len(UTM))])
UTM_N = np.array([int(float(UTM[i][1])) for i in xrange(len(UTM))])

# %%
plt.plot(long_y,lat_x,'ok')
plt.xlim()
plt.ylim()
# Out:
# (-25.0, -20.0)

# %%
areaxy = (np.min(long_y)-5,np.max(long_y)+5,np.min(lat_x)-5,np.max(lat_x)+5)
print(areaxy)
shapexy = (30,30)
# Out:
# (-52.0, -39.0, -30.0, -15.0398)

# %%
fig = plt.figure(figsize=(20,10))
#mpl.title("Profundidade de Moho")
x, y, z = gridder.interp(long_y, lat_x, prof, shapexy, algorithm = 'nearest', area = areaxy, extrapolate = True)
mpl.contour(x, y, z, shapexy, 15, interp = False, extrapolate = True)
mpl.contourf(x, y, z, shapexy, 15, interp = False, extrapolate = False, cmap='Blues')
mpl.plot(long_y,lat_x, '^k', markersize=10)
mpl.plot(long_y,lat_x, '^k', markersize=10)
#mpl.scatter(long_y,lat_x,s=100,c=prof,vmin=min(prof), vmax=max(prof),cmap='bone')
for label, X, Y in zip(labels, long_y,lat_x):
    mpl.annotate(label,xy=(X,Y), xytext=(-1, 1), ha='right',
                textcoords='offset points',fontsize = 8)
'''for shape in lc.shapes():
# adding polygon(s)
    parts = list(shape.parts) + [len(shape.points)]
    partlims = zip(parts[:-1], parts[1:])
    for i1, i2 in partlims:
        points = shape.points[i1:i2]
        x3, y3 = zip(*points)
        plt.plot(x3,y3 , '-', lw=0.1, color='k')'''
for shape in hidro1.shapes():
# adding polygon(s)
    parts = list(shape.parts) + [len(shape.points)]
    partlims = zip(parts[:-1], parts[1:])
    for i1, i2 in partlims:
        points = shape.points[i1:i2]
        x5, y5 = zip(*points)
        plt.plot(x5,y5 , '-', lw=0.3, color='blue')
for shape in hidro2.shapes():
# adding polygon(s)
    parts = list(shape.parts) + [len(shape.points)]
    partlims = zip(parts[:-1], parts[1:])
    for i1, i2 in partlims:
        points = shape.points[i1:i2]
        x6, y6 = zip(*points)
        plt.plot(x6,y6 , '-', lw=0.5, color='blue')
for shape in tc.shapes():
# adding polygon(s)
    parts = list(shape.parts) + [len(shape.points)]
    partlims = zip(parts[:-1], parts[1:])
    for i1, i2 in partlims:
        points = shape.points[i1:i2]
        x2, y2 = zip(*points)
        plt.plot(x2,y2 , '-', lw=1, color='gray')
for shape in bat.shapes():
# adding polygon(s)
    parts = list(shape.parts) + [len(shape.points)]
    partlims = zip(parts[:-1], parts[1:])
    for i1, i2 in partlims:
        points = shape.points[i1:i2]
        x4, y4 = zip(*points)
        plt.plot(x4,y4 , '-', lw=0.5, color='k')
for shape in sf.shapes():
# adding polygon(s)
    parts = list(shape.parts) + [len(shape.points)]
    partlims = zip(parts[:-1], parts[1:])
    for i1, i2 in partlims:
        points = shape.points[i1:i2]
        x1, y1 = zip(*points)
        plt.plot(x1,y1 , '-', lw=1, color='k')
mpl.colorbar()
mpl.axis('normal')
mpl.set_area(areaxy)
mpl.ylim(-26.5,-20.5)
mpl.xlim(-47.55,-44.5)
#mpl.m2km()
mpl.savefig('Interpolacao Linear  - Profundidade de Moho.png',dpi=200)
mpl.show()
# Out:
# /home/diogo/programas/anaconda/lib/python2.7/site-packages/matplotlib/contour.py:483: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   nlc.append(np.r_[lc[:I[0] + 1], xy1])
# /home/diogo/programas/anaconda/lib/python2.7/site-packages/matplotlib/contour.py:485: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   nlc.append(np.r_[xy2, lc[I[1]:]])
# /home/diogo/programas/anaconda/lib/python2.7/site-packages/matplotlib/contour.py:483: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   nlc.append(np.r_[lc[:I[0] + 1], xy1])
# /home/diogo/programas/anaconda/lib/python2.7/site-packages/matplotlib/contour.py:485: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   nlc.append(np.r_[xy2, lc[I[1]:]])
# ...

# %%
plt.subplots_adjust(top=1,left=0,bottom=0,wspace=0.3)
plt.subplot(131)
mpl.title("Interpolacao Nearest")
x, y, z = gridder.interp(UTM_E, UTM_N, prof, shapexy, algorithm = 'nearest', area = areaxy, extrapolate = True)
mpl.contourf(x, y, z, shapexy, 100, interp = False, extrapolate = False,cmap='bone')
mpl.plot(UTM_E, UTM_N, '.k')
for label, X, Y in zip(labels, UTM_E, UTM_N):
    mpl.annotate(label,xy=(X,Y), xytext=(-2, 2), ha='right',
                textcoords='offset points',fontsize = 6)
mpl.colorbar()
mpl.set_area(areaxy)
mpl.m2km()
plt.subplot(132)
mpl.title("Interpolacao Linear")
x, y, z = gridder.interp(UTM_E, UTM_N, prof, shapexy, algorithm = 'linear', area = areaxy, extrapolate = True)
mpl.contourf(x, y, z, shapexy, 100, interp = False, extrapolate = False,cmap='bone')
mpl.plot(UTM_E, UTM_N, '.k')
for label, X, Y in zip(labels, UTM_E, UTM_N):
    mpl.annotate(label,xy=(X,Y), xytext=(-2, 2), ha='right',
                textcoords='offset points',fontsize = 6)
mpl.colorbar()
mpl.set_area(areaxy)
mpl.m2km()
mpl.subplot(133)
mpl.title("Interpolacao Cubic")
x, y, z = gridder.interp(UTM_E, UTM_N, prof, shapexy, algorithm = 'cubic', area = areaxy, extrapolate = True)
mpl.contourf(x, y, z, shapexy, 100, interp = False, extrapolate = False,cmap='bone')
mpl.plot(UTM_E, UTM_N, '.k')
for label, X, Y in zip(labels, UTM_E, UTM_N):
    mpl.annotate(label,xy=(X,Y), xytext=(-2, 2), ha='right',
                textcoords='offset points',fontsize = 6)
mpl.colorbar()
mpl.set_area(areaxy)
mpl.m2km()
mpl.gcf().set_size_inches(15,3)
mpl.savefig('Interpolacao - NM - Profundidade de Moho.png',dpi=500)
mpl.show()
