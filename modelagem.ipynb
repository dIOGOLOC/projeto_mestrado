# %% [markdown]
# <h1>Script para plotar as funções do Receptor Sintéticas</h1>
#
# <h4>O principal módulo utilizado é o obspy.
# Módulos como os e shutil são utilizados em algumas rotinas de busca e conversão de dados. O módulo pyplot é para plotar os dados e o módulos gridspec para configurar o grid do plot.</h4>

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from __future__ import print_function
import numpy as np
import matplotlib.pyplot as plt
import obspy
import os
import shutil

# %%
shutil.copyfile("/home/diogo/programas/RFModeling/05_vel.sac",'/home/diogo/diogo_git/projeto_mestrado/05_vel.sac')

# %%
perfil1 = ['01','02','03','04','05']
dist_perfil1 = np.array([0,20,40,60,80])/10

# %%
STdados = {'st':[],'data':[],'time':[]}

# %%
STdados['st'] = obspy.read('*.sac')
STdados['data'] = [i.data for i in STdados['st']]
STdados['time'] = [i.times() for i in STdados['st']]

# %%
fig, ax = plt.subplots(nrows=1, ncols=5, figsize=(20,6))
ax[0].vlines(6.6,0,-12,'k',linewidth=3)
ax[0].hlines(-12,6.6,6.4,'k',linewidth=3)
ax[0].vlines(6.4,-12,-20,'k',linewidth=3)
ax[0].hlines(-20,6.4,6.7,'k',linewidth=3)
ax[0].vlines(6.7,-20,-32,'k',linewidth=3)
ax[0].hlines(-32,6.7,8.1,'k',linewidth=3)
ax[0].vlines(8.1,-32,-50,'k',linewidth=3)
ax[0].set_xlim(3,9)
ax[0].set_ylim(-50,0)
ax[0].set_xlabel('Velocidade Onda P (km/s)')
ax[0].set_ylabel('Profundidade (km)')
ax[1].vlines(6.6,0,-10,'k',linewidth=3)
ax[1].hlines(-10,6.6,6.4,'k',linewidth=3)
ax[1].vlines(6.4,-10,-20,'k',linewidth=3)
ax[1].hlines(-20,6.4,6.7,'k',linewidth=3)
ax[1].vlines(6.7,-20,-34,'k',linewidth=3)
ax[1].hlines(-34,6.7,8.1,'k',linewidth=3)
ax[1].vlines(8.1,-34,-50,'k',linewidth=3)
ax[1].set_xlim(3,9)
ax[1].set_ylim(-50,0)
ax[1].set_xlabel('Velocidade Onda P (km/s)')
ax[2].vlines(6.6,0,-8,'k',linewidth=3)
ax[2].hlines(-8,6.6,6.4,'k',linewidth=3)
ax[2].vlines(6.4,-8,-20,'k',linewidth=3)
ax[2].hlines(-20,6.4,6.7,'k',linewidth=3)
ax[2].vlines(6.7,-20,-36,'k',linewidth=3)
ax[2].hlines(-36,6.7,8.1,'k',linewidth=3)
ax[2].vlines(8.1,-36,-50,'k',linewidth=3)
ax[2].set_xlim(3,9)
ax[2].set_ylim(-50,0)
ax[2].set_xlabel('Velocidade Onda P (km/s)')
ax[3].vlines(6.6,0,-6,'k',linewidth=3)
ax[3].hlines(-6,6.6,6.4,'k',linewidth=3)
ax[3].vlines(6.4,-6,-20,'k',linewidth=3)
ax[3].hlines(-20,6.4,6.7,'k',linewidth=3)
ax[3].vlines(6.7,-20,-38,'k',linewidth=3)
ax[3].hlines(-38,6.7,8.1,'k',linewidth=3)
ax[3].vlines(8.1,-38,-50,'k',linewidth=3)
ax[3].set_xlim(3,9)
ax[3].set_ylim(-50,0)
ax[3].set_xlabel('Velocidade Onda P (km/s)')
ax[4].vlines(6.6,0,-4,'k',linewidth=3)
ax[4].hlines(-4,6.6,6.4,'k',linewidth=3)
ax[4].vlines(6.4,-4,-20,'k',linewidth=3)
ax[4].hlines(-20,6.4,6.7,'k',linewidth=3)
ax[4].vlines(6.7,-20,-40,'k',linewidth=3)
ax[4].hlines(-40,6.7,8.1,'k',linewidth=3)
ax[4].vlines(8.1,-40,-50,'k',linewidth=3)
ax[4].set_xlim(3,9)
ax[4].set_ylim(-50,0)
ax[4].set_xlabel('Velocidade Onda P (km/s)')

# %%
fig, ax = plt.subplots()
fig.patch.set_facecolor('white')
for i in xrange(len(STdados['st'])):
    ax.plot(STdados['time'][i]-5,STdados['data'][i]*10+dist_perfil1[i], 'k', linewidth=1)
    ax.fill_between(STdados['time'][i]-5,STdados['data'][i]*10+dist_perfil1[i],dist_perfil1[i], where = STdados['data'][i]*10+dist_perfil1[i]>=dist_perfil1[i], facecolor='black',alpha=0.8, interpolate=True)
    ax.fill_between(STdados['time'][i]-5,STdados['data'][i]*10+dist_perfil1[i],dist_perfil1[i], where = STdados['data'][i]*10+dist_perfil1[i]<=dist_perfil1[i], facecolor='gray',alpha=0.5, interpolate=True)
    ax.set_xlim(-2,20)
    ax.text(-3,dist_perfil1[i]+0.5,perfil1[i],rotation=90,fontsize=8)
    #plt.text(21,140,'Distance (km)',rotation=90,fontsize=20)
    ax.tick_params(axis='y', labelleft='off', labelright='off',direction=180,pad=10)
    ax.spines['bottom'].set_bounds(-2, 20)
    ax.spines['left'].set_bounds(0, 10)
    # Hide the right and top spines
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    ax.xaxis.set_ticks_position('bottom')
    plt.xticks(rotation=90)    
    #ax.xaxis.set_ticks_position('left')
    #ax.setp(plt.yticks()[1], rotation=90,fontsize=7)
    ax.set_xlabel(u'Atraso após P(s)',rotation=180,fontsize=9)
    ax.set_ylim(-1,12)
    plt.savefig('Perfil das Funções do Receptor  Sintético.png',dpi=300)

# %%
a = obspy.read('Bassini_1986_Model.sac')
b = a[0]
c = obspy.read('Serra_Mar_Model.sac')
d = c[0]
e = obspy.read('Ribeira_Belt_Model.sac')
f = e[0]
g = obspy.read('middle_crust_model.sac')
h = g[0]

# %% [markdown]
# <h1>Plotando os modelos de Velocidade de Bassini(1986)</h1>

# %%
plt.figure(figsize=(6,10))
plt.vlines(5.6,0,-6,'k')
plt.hlines(-6,5.6,6.6,'k')
plt.vlines(6.6,-6,-33,'k')
plt.hlines(-33,6.6,8.1,'k')
plt.vlines(8.1,-33,-60,'k')
plt.xlim(3,9)
plt.xlabel('Velocidade Onda P (km/s)')
plt.ylabel('Profundidade (km)')

# %%
plt.figure(figsize=(10,5))
plt.plot(b.times()-5,b.data,'k',linewidth=1)
plt.fill_between(b.times()-5,b.data,0,where=b.data>=0,facecolor='black',alpha=0.7, interpolate=True)
plt.fill_between(b.times()-5,b.data,0,where=b.data<=0, facecolor='gray',alpha=0.7, interpolate=True)
plt.text(25,max(f.data)-0.1,'Bassini(1986)',fontsize=15)
plt.yticks([])
plt.xticks([])
plt.xlim(-3,35)
# Out:
# (-3, 35)

# %% [markdown]
# <h1>Plotando o modelos de Velocidade da Serra do Mar</h1>

# %%
plt.figure(figsize=(6,10))
plt.vlines(5.6,0,-6,'k')
plt.hlines(-6,5.6,6.6,'k')
plt.vlines(6.6,-6,-20,'k')
plt.hlines(-20,6.6,6.7,'k')
plt.vlines(6.7,-20,-33,'k')
plt.hlines(-33,6.7,8.1,'k')
plt.vlines(8.1,-33,-60,'k')
plt.xlim(3,9)
plt.xlabel('Velocidade Onda P (km/s)')
plt.ylabel('Profundidade (km)')

# %%
plt.figure(figsize=(10,5))
plt.plot(d.times()-5,d.data,'k',linewidth=1)
plt.fill_between(d.times()-5,d.data,0,where=d.data>=0,facecolor='black',alpha=0.7, interpolate=True)
plt.fill_between(d.times()-5,d.data,0,where=d.data<=0, facecolor='gray',alpha=0.7, interpolate=True)
plt.text(20,max(f.data)-0.1,'Serra do Mar (Franca,2004)',fontsize=15)
plt.yticks([])
plt.xticks([])
plt.xlim(-3,35)
# Out:
# (-3, 35)

# %% [markdown]
# <h1>Plotando o modelo de Velocidade crescente da Faixa Ribeira</h1>

# %%
plt.figure(figsize=(6,10))
plt.vlines(5.4,0,-3,'k')
plt.hlines(-3,5.4,5.6,'k')
plt.vlines(5.6,-3,-6,'k')
plt.hlines(-6,5.6,5.8,'k')
plt.vlines(5.8,-6,-9,'k')
plt.hlines(-9,5.8,6.0,'k')
plt.vlines(6.0,-9,-12,'k')
plt.hlines(-12,6.0,6.2,'k')
plt.vlines(6.2,-12,-15,'k')
plt.hlines(-15,6.2,6.4,'k')
plt.vlines(6.4,-15,-18,'k')
plt.hlines(-18,6.4,6.6,'k')
plt.vlines(6.6,-18,-21,'k')
plt.hlines(-21,6.6,6.8,'k')
plt.vlines(6.8,-21,-24,'k')
plt.hlines(-24,6.8,7,'k')
plt.vlines(7,-24,-27,'k')
plt.hlines(-27,7,7.2,'k')
plt.vlines(7.2,-27,-30,'k')
plt.hlines(-30,7.2,7.4,'k')
plt.vlines(7.4,-30,-33,'k')
plt.hlines(-33,7.4,8,'k')
plt.vlines(8,-33,-60,'k')
plt.xlim(3,9)
plt.xlabel('Velocidade Onda P (km/s)')
plt.ylabel('Profundidade (km)')

# %%
plt.figure(figsize=(10,5))
plt.plot(f.times()-5,f.data,'k',linewidth=1)
plt.fill_between(f.times()-5,f.data,0,where=f.data>=0,facecolor='black',alpha=0.7, interpolate=True)
plt.fill_between(f.times()-5,f.data,0,where=f.data<=0, facecolor='gray',alpha=0.7, interpolate=True)
plt.yticks([])
plt.xlabel('Tempo apos Onda P (s)')
plt.text(20,max(f.data)-0.1,'Sintetico (Franca,2004)',fontsize=15)
plt.xlim(-3,35)
# Out:
# (-3, 35)

# %% [markdown]
# <h1>Plotando o modelos de Velocidade com uma crosta média na Faixa Ribeira</h1>

# %%
plt.figure(figsize=(6,10))
plt.vlines(5.6,0,-5,'k')
plt.hlines(-5,5.6,6.2,'k')
plt.vlines(6.2,-5,-20,'k')
plt.hlines(-20,6.2,6.5,'k')
plt.vlines(6.5,-20,-33,'k')
plt.hlines(-33,6.5,8.1,'k')
plt.vlines(8.1,-33,-60,'k')
plt.xlim(3,9)
plt.xlabel('Velocidade Onda P (km/s)')
plt.ylabel('Profundidade (km)')

# %%
plt.figure(figsize=(10,5))
plt.plot(h.times()-5,h.data,'k',linewidth=1)
plt.fill_between(h.times()-5,h.data,0,where=h.data>=0,facecolor='black',alpha=0.7, interpolate=True)
plt.fill_between(h.times()-5,h.data,0,where=h.data<=0, facecolor='gray',alpha=0.7, interpolate=True)
plt.yticks([])
plt.xlabel('Tempo apos Onda P (s)')
plt.text(20,max(h.data)-0.1,'Solon-Silva(2014)',fontsize=15)
plt.xlim(-3,35)
# Out:
# (-3, 35)

# %% [markdown]
# <h1>Plotando todos os modelos de Velocidade para a Faixa Ribeira</h1>

# %%
plt.figure(figsize=(6,10))
plt.vlines(5.6,0,-6,'r','dashed',label='Bassini(1986)')
plt.hlines(-6,5.6,6.6,'r','dashed')
plt.vlines(6.6,-6,-33,'r','dashed')
plt.hlines(-33,6.6,8.1,'r','dashed')
plt.vlines(8.1,-33,-60,'r','dashed')
plt.vlines(5.6,0,-5,'k','dashdot',label='Serra do Mar (Franca,2004)')
plt.hlines(-5,5.6,6.6,'k','dashdot')
plt.vlines(6.6,-6,-20,'k','dashdot')
plt.hlines(-20,6.6,6.7,'k','dashdot')
plt.vlines(6.7,-20,-33,'k','dashdot')
plt.hlines(-33,6.7,8.1,'k','dashdot')
plt.vlines(8.1,-33,-60,'k','dashdot')
plt.vlines(5.4,0,-3,'k',label='Sintetico (Franca,2004)')
plt.hlines(-3,5.4,5.6,'k')
plt.vlines(5.6,-3,-6,'k')
plt.hlines(-6,5.6,5.8,'k')
plt.vlines(5.8,-6,-9,'k')
plt.hlines(-9,5.8,6.0,'k')
plt.vlines(6.0,-9,-12,'k')
plt.hlines(-12,6.0,6.2,'k')
plt.vlines(6.2,-12,-15,'k')
plt.hlines(-15,6.2,6.4,'k')
plt.vlines(6.4,-15,-18,'k')
plt.hlines(-18,6.4,6.6,'k')
plt.vlines(6.6,-18,-21,'k')
plt.hlines(-21,6.6,6.8,'k')
plt.vlines(6.8,-21,-24,'k')
plt.hlines(-24,6.8,7,'k')
plt.vlines(7,-24,-27,'k')
plt.hlines(-27,7,7.2,'k')
plt.vlines(7.2,-27,-30,'k')
plt.hlines(-30,7.2,7.4,'k')
plt.vlines(7.4,-30,-33,'k')
plt.hlines(-33,7.4,8,'k')
plt.vlines(8,-33,-60,'k')
plt.vlines(5.6,0,-5,'k','dotted',label='Solon-Silva(2014)')
plt.hlines(-5,5.6,6.2,'k','dotted')
plt.vlines(6.2,-5,-20,'k','dotted')
plt.hlines(-20,6.2,6.5,'k','dotted')
plt.vlines(6.5,-20,-33,'k','dotted')
plt.hlines(-33,6.5,8.1,'k','dotted')
plt.vlines(8.1,-33,-60,'k','dotted')
plt.xlim(3,9)
plt.xlabel('Velocidade Onda P (km/s)')
plt.ylabel('Profundidade (km)')
plt.legend(loc='lower left')

# %%
rm 05_vel.sac

# %%
ls
# Out:
# azimuth_noise.ipynb
# exemplo_propagacao.ipynb
# frames/
# Funções do Receptor e Empilhamento - NE - SLP01.png
# Funções do Receptor e Empilhamento - NE - STA04.png
# Funções do Receptor e Empilhamento - NE - STA08.png
# Funções do Receptor e Empilhamento - NE - STA09.png
# Funções do Receptor e Empilhamento - NE - STA10.png
# Funções do Receptor e Empilhamento - NE - STA15.png
# Funções do Receptor e Empilhamento - NE - STA19.png
# Funções do Receptor e Empilhamento - NE - STA20.png
# Funções do Receptor e Empilhamento - NW - SLP01.png
# Funções do Receptor e Empilhamento - NW - STA01.png
# Funções do Receptor e Empilhamento - NW - STA02.png
# Funções do Receptor e Empilhamento - NW - STA03.png
# Funções do Receptor e Empilhamento - NW - STA04.png
# Funções do Receptor e Empilhamento - NW - STA05.png
# Funções do Receptor e Empilhamento - NW - STA06.png
# Funções do Receptor e Empilhamento - NW - STA07.png
# Funções do Receptor e Empilhamento - NW - STA08.png
# ...
